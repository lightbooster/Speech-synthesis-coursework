# %% [markdown]
# # Reasearch Vocoders

# %%
# !pip install librosa --upgrade
import librosa
import librosa.display
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import IPython.display as ipd
import copy
import time

# !gdown https://drive.google.com/uc?id=110yz4UGIbveLW8ENFI1DjypNXs96q0FZ

y, sr = librosa.load('/content/ex.wav',sr=16000) #Читаем файл
ipd.Audio(y, rate=sr)
# Out:
# Requirement already up-to-date: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.1)
# Requirement already satisfied, skipping upgrade: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied, skipping upgrade: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied, skipping upgrade: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied, skipping upgrade: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied, skipping upgrade: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.0)
# Requirement already satisfied, skipping upgrade: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (20.9)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied, skipping upgrade: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.14.5)
# Requirement already satisfied, skipping upgrade: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied, skipping upgrade: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.0.0)
# Requirement already satisfied, skipping upgrade: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2021.5.30)
# Downloading...
# From: https://drive.google.com/uc?id=110yz4UGIbveLW8ENFI1DjypNXs96q0FZ
# To: /content/ex.wav
# 100% 317k/317k [00:00<00:00, 2.78MB/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Creation of Hparams class

# %%
class Hparams():
  def __init__(self, sr):
    self.n_fft = int(sr * 25 / 1000)
    self.hop_length=int(sr * 10 / 1000)
    self.n_mels = 40
    self.n_iter = 10
    self.win_length = 20

# %% [markdown]
# ## Get Spectr

# %%
hp = Hparams(sr)
# Spectr
spectr = librosa.stft(y=y,hop_length=hp.hop_length,n_fft=hp.n_fft)
# Amplitude
ampl = np.abs(spectr) 
# Phase
phasa = np.angle(spectr)
# Signal with amplitude
y_ampl = librosa.istft(ampl,hop_length=hp.hop_length)
ipd.Audio(y_ampl, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# We can see, that the sound, restored only by the amplitude, is very poor quality

# %% [markdown]
# ### Return the phase

# %%
# Add phase
ampl_phasa =  ampl*np.cos(phasa) + 1j*ampl*np.sin(phasa)
# Signal with amplitude and phase
y_ampl_phasa = librosa.istft(ampl_phasa,hop_length=hp.hop_length)
ipd.Audio(y_ampl_phasa, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The sound is very good

# %% [markdown]
# ## Get Melspectrogram

# %%
melspectr = librosa.feature.melspectrogram( 
    y,
    sr,
    n_fft=hp.n_fft,
    hop_length=hp.hop_length,
    n_mels=hp.n_mels
)

# For showing
S_dB = librosa.power_to_db(melspectr, ref=np.max)
plt.figure(figsize=(10, 4))
cmap = cm.get_cmap('viridis')
librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', cmap=cmap)
plt.colorbar()
plt.title('Melspectrogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Return melspectrogram to audio

# %%
ampl_mel = librosa.feature.inverse.mel_to_stft(melspectr, sr, n_fft=hp.n_fft)
y_mel_ampl = librosa.istft(ampl_mel,hop_length=hp.hop_length)
ipd.Audio(y_mel_ampl, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The sound is expectedly bad

# %% [markdown]
# ## Use Griffin-Lim

# %%
y_griffinlim = librosa.griffinlim(ampl_mel, hop_length=hp.hop_length)
ipd.Audio(y_griffinlim, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Return to Mel-phase

# %%
ampl_phasa =  ampl_mel*np.cos(phasa) + 1j*ampl_mel*np.sin(phasa)
y_mel_ampl_phasa = librosa.istft(ampl_phasa,hop_length=hp.hop_length)
ipd.Audio(y_mel_ampl_phasa, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Xdb = 10.0 * np.log10(ampl**2 + 1e-10)
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
librosa.display.specshow(phasa, sr=sr, x_axis='time', y_axis='hz')

# %% [markdown]
# ## Show all graphics

# %%
plt.figure(figsize=(16, 12))
ax = plt.subplot(5,1,1)
librosa.display.waveplot(y, sr=sr, color='b')
plt.title('Original')
plt.xlabel('')
plt.subplot(5,1,2, sharex=ax, sharey=ax)
librosa.display.waveplot(y_ampl, sr=sr, color='r')
plt.title('Only Amplitude')
plt.xlabel('')
plt.subplot(5,1,3, sharex=ax, sharey=ax)
librosa.display.waveplot(y_mel_ampl, sr=sr, color='r')
plt.title('Only Amplitude, that is to get from Mel')
plt.xlabel('')
plt.subplot(5,1,4, sharex=ax, sharey=ax)
librosa.display.waveplot(y_griffinlim, sr=sr, color='g')
plt.title('Only Amplitude, that is to get from Mel + griffinlim')
plt.xlabel('')
plt.subplot(5,1,5, sharex=ax, sharey=ax)
librosa.display.waveplot(y_mel_ampl_phasa, sr=sr, color='r')
plt.title('Amplitude and phase, that is to get Mel')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Сonclusions

# %% [markdown]
# Although the main information is contained in the amplitude, it is impossible to recover a quality signal without phase information. You can try to use the Griffin-Lim algorithm, but it does not give a high-quality signal either.
#
# By its nature, the amplitude spectrum contains many characteristic regions that the network can learn and reconstruct. The phase spectrum, on the other hand, is very random and difficult to reconstruct.
#
# That is why the existing algorithms first obtain a spectrum, and only then receive a signal from it, without phase prediction.

# %% [markdown]
# ## MelGan

# %% [markdown]
# The existing models are mainly autoregressive, which means that the chunks of sound are generated sequentially, which means that the speed of their operation is not very high.
#
# The authors of the article decided to use the GAN network, which until then was usually used for working with pictures, to convert the melspectrum into raw sound.
#
# The architecture consists of a MelGAN generator, 4 transposed convolutions and 3 * 4 Residual blocks. And also three discriminators, each of which contains 4 lowering convolutions. The second and third discriminators receive the signal compressed by 2 and 4 times, respectively, which allows more attention to the lower frequencies.

# %%
# !git clone https://github.com/vlomme/MelGan-WavGan.git
# Out:
# Cloning into 'MelGan-WavGan'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 53 (delta 25), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
cd MelGan-WavGan/
# Out:
# /content/MelGan-WavGan

# %%
# !gdown https://drive.google.com/uc?id=10tLduS5fGNWby7IKvfltuIfUWUeAp9SM
# !unzip logs.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10tLduS5fGNWby7IKvfltuIfUWUeAp9SM
# To: /content/MelGan-WavGan/logs.zip
# 653MB [00:20, 31.4MB/s]
# Archive:  logs.zip
#    creating: logs/
#   inflating: logs/again_40k.pth
#   inflating: logs/mel_ckpt_51k.pt
#   inflating: logs/wav_ckpt_27k.pt
#   inflating: gen/000000_RUSLAN.mel
#   inflating: gen/000001_RUSLAN.mel
#   inflating: gen/nada.wav
#   inflating: gen/o1.wav
#   inflating: gen/o2.wav
#    creating: gen/orig/
#   inflating: gen/orig/000000_RUSLAN.wav
#   inflating: gen/orig/000001_RUSLAN.wav
#   inflating: gen/orig/RUSLAN.wav
#   inflating: gen/RUSLAN.wav
#   inflating: gen/wav-batch_0_sentence_0-mel.wav

# %% [markdown]
# ## Synthesize from mel-spectrogramm

# %%
# !python melgan.py -r g -f mel
# Out:
# Чекпоинт загружен: Эпоха 298, Шаг 518000
# 100% 2/2 [00:01<00:00,  1.81it/s]

# %% [markdown]
# ### Original voice

# %%
y_orig, sr = librosa.load('./gen/orig/000000_RUSLAN.wav',sr=16000)
ipd.Audio(y_orig, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### MelGAN vocoder

# %%
y_melgan, sr = librosa.load('./gen/output/mel_000000_RUSLAN.wav',sr=16000)
ipd.Audio(y_melgan, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Sythesize with Griffin-Lim

# %%
# !python melgan.py -r g -f wav
# Out:
# Чекпоинт загружен: Эпоха 298, Шаг 518000
# 100% 5/5 [00:03<00:00,  1.57it/s]

# %% [markdown]
# ### Original voice

# %%
y_orig, sr = librosa.load('./gen/orig/RUSLAN.wav',sr=16000)
ipd.Audio(y_orig, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Griffin-Lim Algorithm

# %%
y_griffinlim, sr = librosa.load('./gen/RUSLAN.wav',sr=16000)
ipd.Audio(y_griffinlim, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### MelGan vocoder

# %%
y_melgan, sr = librosa.load('./gen/output/mel_RUSLAN.wav',sr=16000)
ipd.Audio(y_melgan, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# My experiments have shown that the model gives good quality, slightly worse than WaveRNN, but works much faster. To improve the quality, you either need to train the model for much longer, or try other approaches.
#
# From the shortcomings, it can be noted that the model requires a melspectrogram in the format in which it was trained, which requires coordination and retraining for specific synthesizer models.

# %% [markdown]
# ## WavGan

# %% [markdown]
# Idea. Why synthesize from a melspectrogram, if you can use Griffin-Lim and get a signal that is very similar to the original sound and you just need to correct it. This approach led to the development of WavGan. Its generator structure is similar to U-net, and the discriminator is taken from MelGAN. Such a model learns much faster, does not require tuning for various synthesizers, can potentially remove noise and gives a quality similar to MelGAN.

# %% [markdown]
# ### Sythesize from mel-spectrogramm

# %%
# !python wavgan.py -r g -f mel
# Out:
# Чекпоинт загружен: Эпоха 108, Шаг 277000
# 100% 2/2 [00:01<00:00,  1.62it/s]

# %%
y_wavgan, sr = librosa.load('./gen/output/wav_000000_RUSLAN.wav',sr=16000)
ipd.Audio(y_wavgan, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Griffin-Lim Algorithm

# %%
# !python wavgan.py -r g -f wav
# Out:
# Чекпоинт загружен: Эпоха 108, Шаг 277000
# 100% 5/5 [00:03<00:00,  1.35it/s]

# %%
y_wavgan, sr = librosa.load('./gen/output/wav_RUSLAN.wav',sr=16000)
ipd.Audio(y_wavgan, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## WavGan with TTS

# %%
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow-gpu==1.14.0
# !sudo apt-get install portaudio19-dev
# !pip install PyAudio
# !pip install sounddevice
# !pip install unidecode

# !gdown https://drive.google.com/uc?id=19Gl9ejMUm_ll6cKozt5N99qDBN25FXDA
# !unzip test.zip
# Out:
# Uninstalling tensorflow-2.5.0:
#   Successfully uninstalled tensorflow-2.5.0
# Collecting tensorflow-gpu==1.14.0
#   Downloading https://files.pythonhosted.org/packages/32/67/559ca8408431c37ad3a17e859c8c291ea82f092354074baef482b98ffb7b/tensorflow_gpu-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (377.1MB)
#      |████████████████████████████████| 377.1MB 32kB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 36.4MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.6MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.12.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.19.5)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 47.7MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.36.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.34.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (3.12.4)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (57.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (3.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (4.5.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.4.1)
# Installing collected packages: tensorboard, keras-applications, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libportaudio2 libportaudiocpp0
# Suggested packages:
#   portaudio19-doc
# The following NEW packages will be installed:
#   libportaudio2 libportaudiocpp0 portaudio19-dev
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 184 kB of archives.
# After this operation, 891 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudiocpp0 amd64 19.6.0-1 [15.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 portaudio19-dev amd64 19.6.0-1 [104 kB]
# Fetched 184 kB in 1s (177 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1) ...
# Selecting previously unselected package libportaudiocpp0:amd64.
# Preparing to unpack .../libportaudiocpp0_19.6.0-1_amd64.deb ...
# Unpacking libportaudiocpp0:amd64 (19.6.0-1) ...
# Selecting previously unselected package portaudio19-dev:amd64.
# Preparing to unpack .../portaudio19-dev_19.6.0-1_amd64.deb ...
# Unpacking portaudio19-dev:amd64 (19.6.0-1) ...
# Setting up libportaudio2:amd64 (19.6.0-1) ...
# Setting up libportaudiocpp0:amd64 (19.6.0-1) ...
# Setting up portaudio19-dev:amd64 (19.6.0-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting PyAudio
#   Downloading https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: PyAudio
#   Building wheel for PyAudio (setup.py) ... done
#   Created wheel for PyAudio: filename=PyAudio-0.2.11-cp37-cp37m-linux_x86_64.whl size=52556 sha256=086493ad303fd7cf63bb4530ee270e3450a61aa4630bdd2c99daffdb3defbdfd
#   Stored in directory: /root/.cache/pip/wheels/f4/a8/a4/292214166c2917890f85b2f72a8e5f13e1ffa527c4200dcede
# Successfully built PyAudio
# Installing collected packages: PyAudio
# Successfully installed PyAudio-0.2.11
# Collecting sounddevice
#   Downloading https://files.pythonhosted.org/packages/3d/e9/cf30f70b81c1a7fa97598d2e89fddb16ab798ca6d64182aa8cd2d66794a4/sounddevice-0.4.1-py3-none-any.whl
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.7/dist-packages (from sounddevice) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from CFFI>=1.0->sounddevice) (2.20)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.4.1
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 8.8MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.2.0
# Downloading...
# From: https://drive.google.com/uc?id=19Gl9ejMUm_ll6cKozt5N99qDBN25FXDA
# To: /content/MelGan-WavGan/test.zip
# 1.59GB [00:33, 47.4MB/s]
# Archive:  test.zip
#    creating: test/
#    creating: test/datasets/
#   inflating: test/datasets/audio.py
#   inflating: test/datasets/preprocessor.py
#   inflating: test/datasets/wavenet_preprocessor.py
#  extracting: test/datasets/__init__.py
#    creating: test/datasets/__pycache__/
#   inflating: test/datasets/__pycache__/audio.cpython-36.pyc
#   inflating: test/datasets/__pycache__/audio.cpython-37.pyc
#   inflating: test/datasets/__pycache__/preprocessor.cpython-36.pyc
#   inflating: test/datasets/__pycache__/preprocessor.cpython-37.pyc
#   inflating: test/datasets/__pycache__/__init__.cpython-36.pyc
#   inflating: test/datasets/__pycache__/__init__.cpython-37.pyc
#   inflating: test/hparams.py
#   inflating: test/hparamst.py
#   inflating: test/infolog.py
#    creating: test/logs-Tacotron-2/
#   inflating: test/logs-Tacotron-2/mel_ckpt_13k.pt
#    creating: test/logs-Tacotron-2/taco_female/
#   inflating: test/logs-Tacotron-2/taco_female/checkpoint
#   inflating: test/logs-Tacotron-2/taco_female/tacotron_model.ckpt-88000.data-00000-of-00001
#   inflating: test/logs-Tacotron-2/taco_female/tacotron_model.ckpt-88000.index
#   inflating: test/logs-Tacotron-2/taco_female/tacotron_model.ckpt-88000.meta
#    creating: test/logs-Tacotron-2/taco_male/
#   inflating: test/logs-Tacotron-2/taco_male/checkpoint
#   inflating: test/logs-Tacotron-2/taco_male/male.data-00000-of-00001
#   inflating: test/logs-Tacotron-2/taco_male/male.index
#   inflating: test/logs-Tacotron-2/taco_male/male.meta
#    creating: test/logs-Tacotron-2/taco_zueva/
#  extracting: test/logs-Tacotron-2/taco_zueva/checkpoint
#   inflating: test/logs-Tacotron-2/taco_zueva/tacotron_model.ckpt-88600.data-00000-of-00001
#   inflating: test/logs-Tacotron-2/taco_zueva/tacotron_model.ckpt-88600.index
#   inflating: test/logs-Tacotron-2/taco_zueva/tacotron_model.ckpt-88600.meta
#   inflating: test/logs-Tacotron-2/wav_ckpt_27k.pt
#   inflating: test/melgan.py
#   inflating: test/synthesize.py
#    creating: test/tacotron/
#   inflating: test/tacotron/feeder.py
#    creating: test/tacotron/models/
#   inflating: test/tacotron/models/Architecture_wrappers.py
#   inflating: test/tacotron/models/attention.py
#   inflating: test/tacotron/models/custom_decoder.py
#   inflating: test/tacotron/models/helpers.py
#   inflating: test/tacotron/models/modules.py
#   inflating: test/tacotron/models/tacotron.py
#   inflating: test/tacotron/models/__init__.py
#    creating: test/tacotron/models/__pycache__/
#   inflating: test/tacotron/models/__pycache__/Architecture_wrappers.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/Architecture_wrappers.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/attention.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/attention.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/custom_decoder.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/custom_decoder.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/helpers.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/helpers.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/modules.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/modules.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/tacotron.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/tacotron.cpython-37.pyc
#   inflating: test/tacotron/models/__pycache__/__init__.cpython-36.pyc
#   inflating: test/tacotron/models/__pycache__/__init__.cpython-37.pyc
#   inflating: test/tacotron/synthesize.py
#   inflating: test/tacotron/synthesizer.py
#   inflating: test/tacotron/train.py
#    creating: test/tacotron/utils/
#   inflating: test/tacotron/utils/cleaners.py
#   inflating: test/tacotron/utils/cmudict.py
#   inflating: test/tacotron/utils/numbers.py
#   inflating: test/tacotron/utils/plot.py
#   inflating: test/tacotron/utils/symbols.py
#   inflating: test/tacotron/utils/text.py
#   inflating: test/tacotron/utils/__init__.py
#    creating: test/tacotron/utils/__pycache__/
#   inflating: test/tacotron/utils/__pycache__/cleaners.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/cleaners.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/cmudict.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/cmudict.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/numbers.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/numbers.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/plot.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/plot.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/symbols.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/symbols.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/text.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/text.cpython-37.pyc
#   inflating: test/tacotron/utils/__pycache__/__init__.cpython-36.pyc
#   inflating: test/tacotron/utils/__pycache__/__init__.cpython-37.pyc
#  extracting: test/tacotron/__init__.py
#    creating: test/tacotron/__pycache__/
#   inflating: test/tacotron/__pycache__/feeder.cpython-36.pyc
#   inflating: test/tacotron/__pycache__/feeder.cpython-37.pyc
#   inflating: test/tacotron/__pycache__/synthesize.cpython-36.pyc
#   inflating: test/tacotron/__pycache__/synthesize.cpython-37.pyc
#   inflating: test/tacotron/__pycache__/synthesizer.cpython-36.pyc
#   inflating: test/tacotron/__pycache__/synthesizer.cpython-37.pyc
#   inflating: test/tacotron/__pycache__/train.cpython-36.pyc
#   inflating: test/tacotron/__pycache__/train.cpython-37.pyc
#   inflating: test/tacotron/__pycache__/__init__.cpython-36.pyc
#   inflating: test/tacotron/__pycache__/__init__.cpython-37.pyc
#   inflating: test/utils.py
#    creating: test/wavenet_vocoder/
#   inflating: test/wavenet_vocoder/feeder.py
#    creating: test/wavenet_vocoder/models/
#   inflating: test/wavenet_vocoder/models/gaussian.py
#   inflating: test/wavenet_vocoder/models/mixture.py
#   inflating: test/wavenet_vocoder/models/modules.py
#   inflating: test/wavenet_vocoder/models/wavenet.py
#   inflating: test/wavenet_vocoder/models/__init__.py
#    creating: test/wavenet_vocoder/models/__pycache__/
#   inflating: test/wavenet_vocoder/models/__pycache__/gaussian.cpython-36.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/gaussian.cpython-37.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/mixture.cpython-36.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/mixture.cpython-37.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/modules.cpython-36.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/modules.cpython-37.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/wavenet.cpython-36.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/wavenet.cpython-37.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/__init__.cpython-36.pyc
#   inflating: test/wavenet_vocoder/models/__pycache__/__init__.cpython-37.pyc
#   inflating: test/wavenet_vocoder/synthesize.py
#   inflating: test/wavenet_vocoder/synthesizer.py
#   inflating: test/wavenet_vocoder/train.py
#   inflating: test/wavenet_vocoder/util.py
#  extracting: test/wavenet_vocoder/__init__.py
#    creating: test/wavenet_vocoder/__pycache__/
#   inflating: test/wavenet_vocoder/__pycache__/feeder.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/feeder.cpython-37.pyc
#   inflating: test/wavenet_vocoder/__pycache__/synthesize.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/synthesize.cpython-37.pyc
#   inflating: test/wavenet_vocoder/__pycache__/synthesizer.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/synthesizer.cpython-37.pyc
#   inflating: test/wavenet_vocoder/__pycache__/train.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/train.cpython-37.pyc
#   inflating: test/wavenet_vocoder/__pycache__/util.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/util.cpython-37.pyc
#   inflating: test/wavenet_vocoder/__pycache__/__init__.cpython-36.pyc
#   inflating: test/wavenet_vocoder/__pycache__/__init__.cpython-37.pyc
#   inflating: test/wavgan.py
#    creating: test/__pycache__/
#   inflating: test/__pycache__/hparams.cpython-37.pyc
#   inflating: test/__pycache__/hparamst.cpython-37.pyc
#   inflating: test/__pycache__/infolog.cpython-37.pyc
#   inflating: test/__pycache__/utils.cpython-37.pyc

# %%
cd test/
# Out:
# /content/MelGan-WavGan/test

# %%
# !python synthesize.py --text_list 'Здравствуй юность в сопогах' --checkpoint male
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/MelGan-WavGan/test/tacotron/models/modules.py:81: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# Traceback (most recent call last):
#   File "synthesize.py", line 11, in <module>
#     from wavenet_vocoder.synthesize import wavenet_synthesize
#   File "/content/MelGan-WavGan/test/wavenet_vocoder/synthesize.py", line 9, in <module>
#     from wavenet_vocoder.synthesizer import Synthesizer
#   File "/content/MelGan-WavGan/test/wavenet_vocoder/synthesizer.py", line 7, in <module>
#     from wavenet_vocoder.models import create_model
#   File "/content/MelGan-WavGan/test/wavenet_vocoder/models/__init__.py", line 1, in <module>
#     from .wavenet import WaveNet
#   File "/content/MelGan-WavGan/test/wavenet_vocoder/models/wavenet.py", line 10, in <module>
#     from .modules import (Conv1D1x1, ConvTranspose2D, ConvTranspose1D, ResizeConvolution, SubPixelConvolution, NearestNeighborUpsample, DiscretizedMixtureLogisticLoss,
#   File "/content/MelGan-WavGan/test/wavenet_vocoder/models/modules.py", line 3, in <module>
#     from keras.utils import np_utils
#   File "/usr/local/lib/python3.7/dist-packages/keras/__init__.py", line 25, in <module>
#     from keras import models
#   File "/usr/local/lib/python3.7/dist-packages/keras/models.py", line 19, in <module>
#     from keras import backend
#   File "/usr/local/lib/python3.7/dist-packages/keras/backend.py", line 37, in <module>
#     from tensorflow.python.eager.context import get_config
# ImportError: cannot import name 'get_config' from 'tensorflow.python.eager.context' (/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/context.py)

# %%
# !python wavgan.py -r g -f wav

# %%
y_tac, sr = librosa.load('./tacotron_output/output/wav_wav-batch_0_sentence_0-mel.wav',sr=16000)
ipd.Audio(y_tac, rate=sr)
